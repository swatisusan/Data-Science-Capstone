# %% [markdown]
# This Notebook covers the first week assignment for the Data Science Capstone Course. The notebook imports pandas and numpy. This notebook is also pushed to github.

# %%
import pandas as pd
import numpy as np
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
