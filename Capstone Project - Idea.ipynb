# %% [markdown]
# ## Capstone Project - Predicting Restaurant type for future business venture in New York City

# %% [markdown]
# # Business Section

# %% [markdown]
# The success of any business venture depands on an indepth study of the market and understanding the business location. Restaurant bussinees survive in areas that are heavily populated, popular or areas with heavy foot traffice. Factors such as the ethinicity of the population can also contribute to the success or failure of a restaurant. This project will analyse the neighburhoods in New York and the type of restaurants that are present in a neighbourhood. Using the information from the analyses I will determine the best option for a future restaurant in each neighbourhood in New York

# %% [markdown]
# # Data for the project

# %%
Use the Foursquare API to explore neighborhoods in New York City. 
Neighbourhood data for New York - https://geo.nyu.edu/catalog/nyu_2451_34572
